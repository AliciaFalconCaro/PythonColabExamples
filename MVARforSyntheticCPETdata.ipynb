# %% [markdown]
# <a href="https://colab.research.google.com/github/AliciaFalconCaro/PythonColabExamples/blob/main/MVARforSyntheticCPETdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##code to be updated based on how it was implemented for the challenge

import numpy as np
import pandas as pd
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests

# Example function to apply VAR model and calculate Granger causality as a matrix
def apply_var_and_granger_as_matrix(data, window_size, overlap, max_lag):
    num_vars = data.shape[1]  # Number of variables
    num_points = len(data)     # Length of time series

    # Step size for overlapping windows (50% overlap)
    step_size = int(window_size * (1 - overlap))

    results_list = []

    variables = data.columns.tolist()

    # Loop over the data with the specified window and overlap
    for start in range(0, num_points - window_size + 1, step_size):
        # Extract the windowed data
        end = start + window_size
        window_data = data.iloc[start:end][variables]


        # Fit a VAR model to the windowed data
        model = VAR(window_data)
        results = model.fit(maxlags=max_lag, ic='aic')

        # Initialize Granger causality matrix
        granger_matrix = np.zeros((num_vars, num_vars))

        # Compute Granger causality for each pair of variables
        for i, var1 in enumerate(variables):
            for j, var2 in enumerate(variables):
                if i != j:  # No need to check causality for the same variable
                    test_result = grangercausalitytests(window_data[[var1, var2]], max_lag)
                    # Collect p-value for the Granger causality test (use max_lag F-test result)
                    p_value = test_result[max_lag][0]['ssr_ftest'][1]
                    granger_matrix[i, j] = p_value

        # Store the matrix along with window time range
        results_list.append({
            'start_time': start,
            'end_time': start + window_size,
            'granger_matrix': granger_matrix
        })

    return results_list

# %%
# Example synthetic dataset

# Parameters
n_time_points = 1000  # Number of time points per subject
n_subjects = 5        # Number of subjects
np.random.seed(42)

# Create an empty list to hold data for all subjects
all_subjects_data = []

for subject in range(1, n_subjects + 1):
    # Generate synthetic time series data for CPET variables (non-stationary with trends)
    vo2 = 20 + 0.05 * np.arange(n_time_points) + np.random.normal(0, 2, n_time_points)
    vco2 = 15 + 0.03 * np.arange(n_time_points) + np.random.normal(0, 1.5, n_time_points)
    heart_rate = 70 + 0.1 * np.arange(n_time_points) + np.random.normal(0, 5, n_time_points)

    # Create a DataFrame for the current subject
    subject_data = pd.DataFrame({
        'VO2': vo2,
        'VCO2': vco2,
        'HeartRate': heart_rate,
        'Subject_ID': subject  # Add a subject identifier
    })

    # Append the subject data to the list
    all_subjects_data.append(subject_data)

# Concatenate all subject data into one DataFrame
combined_data = pd.concat(all_subjects_data, ignore_index=True)

# Print the first few rows of the combined data
#print(combined_data.head())

combined_data.head()
# Out:
#          VO2       VCO2  HeartRate  Subject_ID
# 0  20.993428  17.099033  66.624109           1
# 1  19.773471  16.416951  69.377407           1
# 2  21.395377  15.149446  66.237900           1
# 3  23.196060  14.119595  68.760192           1
# 4  19.731693  16.167335  60.931927           1

# %%
# if we have timestamps, we can convert them to datetime to avoid problems with MVAR and reset the index to the datetime
# Convert 'Timestamp' to datetime format (if you have a timestamp column)
#data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# Set the 'Timestamp' as the index (if you have such a column)
#data.set_index('Timestamp', inplace=True)


normalized_data = combined_data.groupby('Subject_ID').apply(lambda x: (x[['VO2', 'VCO2', 'HeartRate']] - x[['VO2', 'VCO2', 'HeartRate']].mean()) / x[['VO2', 'VCO2', 'HeartRate']].std()).reset_index(drop=True)
# Reattach the Subject column
normalized_data['Subject_ID'] = combined_data['Subject_ID'].values
normalized_data.head()
# Out:
#         VO2      VCO2  HeartRate  Subject_ID
# 0 -1.640518 -1.484533  -1.815320           1
# 1 -1.723837 -1.562470  -1.721643           1
# 2 -1.613066 -1.707299  -1.828460           1
# 3 -1.490084 -1.824973  -1.742643           1
# 4 -1.726691 -1.590992  -2.008987           1

# %%
# Parameters
window_size = 200  # Window size in seconds (assuming 1 second per data point)
overlap = 0.5      # 50% overlap
max_lag = 10        # Maximum lag for VAR/Granger Causality

# Apply VAR and Granger causality to each subject's data over sliding windows
# Out:
# Streaming output truncated to the last 5000 lines.
# ssr based F test:         F=1.4812  , p=0.1582  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=14.8038 , p=0.0965  , df=9
# likelihood ratio test: chi2=14.2581 , p=0.1134  , df=9
# parameter F test:         F=1.4812  , p=0.1582  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1415  , p=0.3343  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=12.8334 , p=0.2331  , df=10
# likelihood ratio test: chi2=12.4185 , p=0.2580  , df=10
# parameter F test:         F=1.1415  , p=0.3343  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=23.4946 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=23.8542 , p=0.0000  , df=1
# likelihood ratio test: chi2=22.5294 , p=0.0000  , df=1
# parameter F test:         F=23.4946 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.9161  , p=0.0005  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=16.2423 , p=0.0003  , df=2
# likelihood ratio test: chi2=15.6105 , p=0.0004  , df=2
# parameter F test:         F=7.9161  , p=0.0005  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.9847  , p=0.0006  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=18.6156 , p=0.0003  , df=3
# likelihood ratio test: chi2=17.7878 , p=0.0005  , df=3
# parameter F test:         F=5.9847  , p=0.0006  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.2319  , p=0.0136  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=13.5496 , p=0.0089  , df=4
# likelihood ratio test: chi2=13.1018 , p=0.0108  , df=4
# parameter F test:         F=3.2319  , p=0.0136  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0380  , p=0.0753  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=10.7990 , p=0.0555  , df=5
# likelihood ratio test: chi2=10.5106 , p=0.0620  , df=5
# parameter F test:         F=2.0380  , p=0.0753  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4200  , p=0.0283  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=15.5630 , p=0.0163  , df=6
# likelihood ratio test: chi2=14.9703 , p=0.0205  , df=6
# parameter F test:         F=2.4200  , p=0.0283  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6428  , p=0.1261  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=12.4688 , p=0.0862  , df=7
# likelihood ratio test: chi2=12.0826 , p=0.0979  , df=7
# parameter F test:         F=1.6428  , p=0.1261  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.5335  , p=0.1486  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=13.4601 , p=0.0970  , df=8
# likelihood ratio test: chi2=13.0093 , p=0.1115  , df=8
# parameter F test:         F=1.5335  , p=0.1486  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2760  , p=0.2531  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=12.7527 , p=0.1741  , df=9
# likelihood ratio test: chi2=12.3450 , p=0.1945  , df=9
# parameter F test:         F=1.2760  , p=0.2531  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0163  , p=0.4318  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=11.4257 , p=0.3253  , df=10
# likelihood ratio test: chi2=11.0954 , p=0.3501  , df=10
# parameter F test:         F=1.0163  , p=0.4318  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=23.2775 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=23.6338 , p=0.0000  , df=1
# likelihood ratio test: chi2=22.3325 , p=0.0000  , df=1
# parameter F test:         F=23.2775 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=14.3476 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=29.4386 , p=0.0000  , df=2
# likelihood ratio test: chi2=27.4454 , p=0.0000  , df=2
# parameter F test:         F=14.3476 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.9479  , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=27.8326 , p=0.0000  , df=3
# likelihood ratio test: chi2=26.0341 , p=0.0000  , df=3
# parameter F test:         F=8.9479  , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.2145  , p=0.0027  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=17.6691 , p=0.0014  , df=4
# likelihood ratio test: chi2=16.9176 , p=0.0020  , df=4
# parameter F test:         F=4.2145  , p=0.0027  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.3362  , p=0.0009  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=22.9771 , p=0.0003  , df=5
# likelihood ratio test: chi2=21.7211 , p=0.0006  , df=5
# parameter F test:         F=4.3362  , p=0.0009  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7617  , p=0.0136  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=17.7605 , p=0.0069  , df=6
# likelihood ratio test: chi2=16.9940 , p=0.0093  , df=6
# parameter F test:         F=2.7617  , p=0.0136  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.3933  , p=0.0231  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=18.1648 , p=0.0112  , df=7
# likelihood ratio test: chi2=17.3601 , p=0.0152  , df=7
# parameter F test:         F=2.3933  , p=0.0231  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.1598  , p=0.0327  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=18.9569 , p=0.0151  , df=8
# likelihood ratio test: chi2=18.0784 , p=0.0206  , df=8
# parameter F test:         F=2.1598  , p=0.0327  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.8721  , p=0.0590  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=18.7098 , p=0.0278  , df=9
# likelihood ratio test: chi2=17.8492 , p=0.0370  , df=9
# parameter F test:         F=1.8721  , p=0.0590  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.6937  , p=0.0857  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=19.0413 , p=0.0397  , df=10
# likelihood ratio test: chi2=18.1465 , p=0.0525  , df=10
# parameter F test:         F=1.6937  , p=0.0857  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.4370  , p=0.0041  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=8.5662  , p=0.0034  , df=1
# likelihood ratio test: chi2=8.3869  , p=0.0038  , df=1
# parameter F test:         F=8.4370  , p=0.0041  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.8024  , p=0.0631  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=5.7500  , p=0.0564  , df=2
# likelihood ratio test: chi2=5.6681  , p=0.0588  , df=2
# parameter F test:         F=2.8024  , p=0.0631  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6343  , p=0.0512  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=8.1941  , p=0.0422  , df=3
# likelihood ratio test: chi2=8.0283  , p=0.0454  , df=3
# parameter F test:         F=2.6343  , p=0.0512  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5825  , p=0.6757  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=2.4420  , p=0.6550  , df=4
# likelihood ratio test: chi2=2.4269  , p=0.6578  , df=4
# parameter F test:         F=0.5825  , p=0.6757  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.8436  , p=0.0169  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=15.0680 , p=0.0101  , df=5
# likelihood ratio test: chi2=14.5142 , p=0.0127  , df=5
# parameter F test:         F=2.8436  , p=0.0169  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7997  , p=0.0125  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=18.0046 , p=0.0062  , df=6
# likelihood ratio test: chi2=17.2175 , p=0.0085  , df=6
# parameter F test:         F=2.7997  , p=0.0125  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.4189  , p=0.0217  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=18.3593 , p=0.0104  , df=7
# likelihood ratio test: chi2=17.5378 , p=0.0142  , df=7
# parameter F test:         F=2.4189  , p=0.0217  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.9902  , p=0.0502  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=17.4684 , p=0.0256  , df=8
# likelihood ratio test: chi2=16.7189 , p=0.0332  , df=8
# parameter F test:         F=1.9902  , p=0.0502  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6384  , p=0.1078  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=16.3740 , p=0.0595  , df=9
# likelihood ratio test: chi2=15.7098 , p=0.0732  , df=9
# parameter F test:         F=1.6384  , p=0.1078  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.0908  , p=0.0277  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=23.5065 , p=0.0090  , df=10
# likelihood ratio test: chi2=22.1622 , p=0.0143  , df=10
# parameter F test:         F=2.0908  , p=0.0277  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=49.8384 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=50.6012 , p=0.0000  , df=1
# likelihood ratio test: chi2=45.0854 , p=0.0000  , df=1
# parameter F test:         F=49.8384 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=20.8746 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=42.8307 , p=0.0000  , df=2
# likelihood ratio test: chi2=38.7738 , p=0.0000  , df=2
# parameter F test:         F=20.8746 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=12.0843 , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=37.5884 , p=0.0000  , df=3
# likelihood ratio test: chi2=34.4018 , p=0.0000  , df=3
# parameter F test:         F=12.0843 , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=6.9696  , p=0.0000  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=29.2202 , p=0.0000  , df=4
# likelihood ratio test: chi2=27.2369 , p=0.0000  , df=4
# parameter F test:         F=6.9696  , p=0.0000  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.5843  , p=0.0006  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=24.2919 , p=0.0002  , df=5
# likelihood ratio test: chi2=22.8938 , p=0.0004  , df=5
# parameter F test:         F=4.5843  , p=0.0006  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=5.1528  , p=0.0001  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=33.1371 , p=0.0000  , df=6
# likelihood ratio test: chi2=30.5930 , p=0.0000  , df=6
# parameter F test:         F=5.1528  , p=0.0001  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=4.1846  , p=0.0003  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=31.7609 , p=0.0000  , df=7
# likelihood ratio test: chi2=29.4030 , p=0.0001  , df=7
# parameter F test:         F=4.1846  , p=0.0003  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=4.2122  , p=0.0001  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=36.9712 , p=0.0000  , df=8
# likelihood ratio test: chi2=33.8113 , p=0.0000  , df=8
# parameter F test:         F=4.2122  , p=0.0001  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.2369  , p=0.0012  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=32.3504 , p=0.0002  , df=9
# likelihood ratio test: chi2=29.8855 , p=0.0005  , df=9
# parameter F test:         F=3.2369  , p=0.0012  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.0164  , p=0.0016  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=33.9126 , p=0.0002  , df=10
# likelihood ratio test: chi2=31.2040 , p=0.0005  , df=10
# parameter F test:         F=3.0164  , p=0.0016  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=33.8570 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=34.3753 , p=0.0000  , df=1
# likelihood ratio test: chi2=31.7092 , p=0.0000  , df=1
# parameter F test:         F=33.8570 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=11.7831 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=24.1767 , p=0.0000  , df=2
# likelihood ratio test: chi2=22.8108 , p=0.0000  , df=2
# parameter F test:         F=11.7831 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.1331  , p=0.0001  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=22.1876 , p=0.0001  , df=3
# likelihood ratio test: chi2=21.0247 , p=0.0001  , df=3
# parameter F test:         F=7.1331  , p=0.0001  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=5.1097  , p=0.0006  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=21.4224 , p=0.0003  , df=4
# likelihood ratio test: chi2=20.3305 , p=0.0004  , df=4
# parameter F test:         F=5.1097  , p=0.0006  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.6803  , p=0.0034  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=19.5018 , p=0.0015  , df=5
# likelihood ratio test: chi2=18.5871 , p=0.0023  , df=5
# parameter F test:         F=3.6803  , p=0.0034  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.9498  , p=0.0090  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=18.9700 , p=0.0042  , df=6
# likelihood ratio test: chi2=18.0989 , p=0.0060  , df=6
# parameter F test:         F=2.9498  , p=0.0090  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0778  , p=0.0482  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=15.7700 , p=0.0273  , df=7
# likelihood ratio test: chi2=15.1588 , p=0.0340  , df=7
# parameter F test:         F=2.0778  , p=0.0482  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7474  , p=0.0906  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=15.3370 , p=0.0529  , df=8
# likelihood ratio test: chi2=14.7552 , p=0.0641  , df=8
# parameter F test:         F=1.7474  , p=0.0906  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3848  , p=0.1983  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=13.8401 , p=0.1281  , df=9
# likelihood ratio test: chi2=13.3617 , p=0.1469  , df=9
# parameter F test:         F=1.3848  , p=0.1983  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2950  , p=0.2368  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=14.5592 , p=0.1490  , df=10
# likelihood ratio test: chi2=14.0284 , p=0.1717  , df=10
# parameter F test:         F=1.2950  , p=0.2368  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=15.2202 , p=0.0001  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=15.4532 , p=0.0001  , df=1
# likelihood ratio test: chi2=14.8825 , p=0.0001  , df=1
# parameter F test:         F=15.2202 , p=0.0001  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.0352  , p=0.0002  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=18.5386 , p=0.0001  , df=2
# likelihood ratio test: chi2=17.7213 , p=0.0001  , df=2
# parameter F test:         F=9.0352  , p=0.0002  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.9881  , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=27.9577 , p=0.0000  , df=3
# likelihood ratio test: chi2=26.1436 , p=0.0000  , df=3
# parameter F test:         F=8.9881  , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=6.0764  , p=0.0001  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=25.4753 , p=0.0000  , df=4
# likelihood ratio test: chi2=23.9505 , p=0.0001  , df=4
# parameter F test:         F=6.0764  , p=0.0001  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.2872  , p=0.0010  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=22.7173 , p=0.0004  , df=5
# likelihood ratio test: chi2=21.4886 , p=0.0007  , df=5
# parameter F test:         F=4.2872  , p=0.0010  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.3706  , p=0.0036  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=21.6761 , p=0.0014  , df=6
# likelihood ratio test: chi2=20.5484 , p=0.0022  , df=6
# parameter F test:         F=3.3706  , p=0.0036  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.5228  , p=0.0169  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=19.1474 , p=0.0077  , df=7
# likelihood ratio test: chi2=18.2561 , p=0.0109  , df=7
# parameter F test:         F=2.5228  , p=0.0169  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3526  , p=0.0199  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=20.6489 , p=0.0081  , df=8
# likelihood ratio test: chi2=19.6122 , p=0.0119  , df=8
# parameter F test:         F=2.3526  , p=0.0199  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.1735  , p=0.0261  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=21.7223 , p=0.0098  , df=9
# likelihood ratio test: chi2=20.5734 , p=0.0147  , df=9
# parameter F test:         F=2.1735  , p=0.0261  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7058  , p=0.0830  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=19.1776 , p=0.0381  , df=10
# likelihood ratio test: chi2=18.2704 , p=0.0506  , df=10
# parameter F test:         F=1.7058  , p=0.0830  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=15.7257 , p=0.0001  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=15.9663 , p=0.0001  , df=1
# likelihood ratio test: chi2=15.3582 , p=0.0001  , df=1
# parameter F test:         F=15.7257 , p=0.0001  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.0339  , p=0.0002  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=18.5359 , p=0.0001  , df=2
# likelihood ratio test: chi2=17.7189 , p=0.0001  , df=2
# parameter F test:         F=9.0339  , p=0.0002  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.0631  , p=0.0002  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=21.9700 , p=0.0001  , df=3
# likelihood ratio test: chi2=20.8290 , p=0.0001  , df=3
# parameter F test:         F=7.0631  , p=0.0002  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.1635  , p=0.0030  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=17.4556 , p=0.0016  , df=4
# likelihood ratio test: chi2=16.7216 , p=0.0022  , df=4
# parameter F test:         F=4.1635  , p=0.0030  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.7354  , p=0.0207  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=14.4949 , p=0.0128  , df=5
# likelihood ratio test: chi2=13.9815 , p=0.0157  , df=5
# parameter F test:         F=2.7354  , p=0.0207  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3777  , p=0.0310  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=15.2908 , p=0.0181  , df=6
# likelihood ratio test: chi2=14.7181 , p=0.0226  , df=6
# parameter F test:         F=2.3777  , p=0.0310  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.4104  , p=0.0222  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=18.2947 , p=0.0107  , df=7
# likelihood ratio test: chi2=17.4788 , p=0.0146  , df=7
# parameter F test:         F=2.4104  , p=0.0222  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.2054  , p=0.0291  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=19.3571 , p=0.0131  , df=8
# likelihood ratio test: chi2=18.4423 , p=0.0181  , df=8
# parameter F test:         F=2.2054  , p=0.0291  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7369  , p=0.0840  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=17.3590 , p=0.0434  , df=9
# likelihood ratio test: chi2=16.6149 , p=0.0551  , df=9
# parameter F test:         F=1.7369  , p=0.0840  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3462  , p=0.2097  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=15.1351 , p=0.1272  , df=10
# likelihood ratio test: chi2=14.5625 , p=0.1488  , df=10
# parameter F test:         F=1.3462  , p=0.2097  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=22.8477 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=23.1974 , p=0.0000  , df=1
# likelihood ratio test: chi2=21.9420 , p=0.0000  , df=1
# parameter F test:         F=22.8477 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.7495 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=26.1595 , p=0.0000  , df=2
# likelihood ratio test: chi2=24.5700 , p=0.0000  , df=2
# parameter F test:         F=12.7495 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=6.8715  , p=0.0002  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=21.3739 , p=0.0001  , df=3
# likelihood ratio test: chi2=20.2920 , p=0.0001  , df=3
# parameter F test:         F=6.8715  , p=0.0002  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.6311  , p=0.0071  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=15.2236 , p=0.0043  , df=4
# likelihood ratio test: chi2=14.6613 , p=0.0055  , df=4
# parameter F test:         F=3.6311  , p=0.0071  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.1516  , p=0.0094  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=16.7000 , p=0.0051  , df=5
# likelihood ratio test: chi2=16.0232 , p=0.0068  , df=5
# parameter F test:         F=3.1516  , p=0.0094  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.9568  , p=0.0089  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=19.0153 , p=0.0041  , df=6
# likelihood ratio test: chi2=18.1401 , p=0.0059  , df=6
# parameter F test:         F=2.9568  , p=0.0089  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0539  , p=0.0509  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=15.5889 , p=0.0291  , df=7
# likelihood ratio test: chi2=14.9913 , p=0.0361  , df=7
# parameter F test:         F=2.0539  , p=0.0509  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.8250  , p=0.0752  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=16.0180 , p=0.0421  , df=8
# likelihood ratio test: chi2=15.3849 , p=0.0521  , df=8
# parameter F test:         F=1.8250  , p=0.0752  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7716  , p=0.0768  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=17.7058 , p=0.0387  , df=9
# likelihood ratio test: chi2=16.9326 , p=0.0498  , df=9
# parameter F test:         F=1.7716  , p=0.0768  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7197  , p=0.0799  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=19.3339 , p=0.0362  , df=10
# likelihood ratio test: chi2=18.4122 , p=0.0484  , df=10
# parameter F test:         F=1.7197  , p=0.0799  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=13.3716 , p=0.0003  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=13.5762 , p=0.0002  , df=1
# likelihood ratio test: chi2=13.1332 , p=0.0003  , df=1
# parameter F test:         F=13.3716 , p=0.0003  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.8678  , p=0.0225  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=7.9361  , p=0.0189  , df=2
# likelihood ratio test: chi2=7.7812  , p=0.0204  , df=2
# parameter F test:         F=3.8678  , p=0.0225  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1853  , p=0.0250  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=9.9080  , p=0.0194  , df=3
# likelihood ratio test: chi2=9.6669  , p=0.0216  , df=3
# parameter F test:         F=3.1853  , p=0.0250  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9894  , p=0.0978  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=8.3404  , p=0.0799  , df=4
# likelihood ratio test: chi2=8.1679  , p=0.0856  , df=4
# parameter F test:         F=1.9894  , p=0.0978  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.1662  , p=0.0597  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=11.4784 , p=0.0427  , df=5
# likelihood ratio test: chi2=11.1532 , p=0.0484  , df=5
# parameter F test:         F=2.1662  , p=0.0597  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7956  , p=0.0126  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=17.9782 , p=0.0063  , df=6
# likelihood ratio test: chi2=17.1933 , p=0.0086  , df=6
# parameter F test:         F=2.7956  , p=0.0126  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1576  , p=0.0401  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=16.3760 , p=0.0219  , df=7
# likelihood ratio test: chi2=15.7182 , p=0.0278  , df=7
# parameter F test:         F=2.1576  , p=0.0401  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.8225  , p=0.0757  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=15.9968 , p=0.0424  , df=8
# likelihood ratio test: chi2=15.3652 , p=0.0524  , df=8
# parameter F test:         F=1.8225  , p=0.0757  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5687  , p=0.1281  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=15.6782 , p=0.0739  , df=9
# likelihood ratio test: chi2=15.0679 , p=0.0891  , df=9
# parameter F test:         F=1.5687  , p=0.1281  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.5452  , p=0.1273  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=17.3724 , p=0.0665  , df=10
# likelihood ratio test: chi2=16.6235 , p=0.0831  , df=10
# parameter F test:         F=1.5452  , p=0.1273  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=63.3740 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=64.3440 , p=0.0000  , df=1
# likelihood ratio test: chi2=55.7511 , p=0.0000  , df=1
# parameter F test:         F=63.3740 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=26.4598 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=54.2905 , p=0.0000  , df=2
# likelihood ratio test: chi2=47.9782 , p=0.0000  , df=2
# parameter F test:         F=26.4598 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=14.5036 , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=45.1137 , p=0.0000  , df=3
# likelihood ratio test: chi2=40.6221 , p=0.0000  , df=3
# parameter F test:         F=14.5036 , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=8.8046  , p=0.0000  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=36.9136 , p=0.0000  , df=4
# likelihood ratio test: chi2=33.8204 , p=0.0000  , df=4
# parameter F test:         F=8.8046  , p=0.0000  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=7.3403  , p=0.0000  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=38.8955 , p=0.0000  , df=5
# likelihood ratio test: chi2=35.4656 , p=0.0000  , df=5
# parameter F test:         F=7.3403  , p=0.0000  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=5.3678  , p=0.0000  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=34.5199 , p=0.0000  , df=6
# likelihood ratio test: chi2=31.7705 , p=0.0000  , df=6
# parameter F test:         F=5.3678  , p=0.0000  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.8306  , p=0.0007  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=29.0741 , p=0.0001  , df=7
# likelihood ratio test: chi2=27.0819 , p=0.0003  , df=7
# parameter F test:         F=3.8306  , p=0.0007  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.7404  , p=0.0005  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=32.8303 , p=0.0001  , df=8
# likelihood ratio test: chi2=30.3073 , p=0.0002  , df=8
# parameter F test:         F=3.7404  , p=0.0005  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.1692  , p=0.0014  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=31.6732 , p=0.0002  , df=9
# likelihood ratio test: chi2=29.3055 , p=0.0006  , df=9
# parameter F test:         F=3.1692  , p=0.0014  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.3116  , p=0.0006  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=37.2309 , p=0.0001  , df=10
# likelihood ratio test: chi2=33.9991 , p=0.0002  , df=10
# parameter F test:         F=3.3116  , p=0.0006  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=33.2929 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=33.8025 , p=0.0000  , df=1
# likelihood ratio test: chi2=31.2202 , p=0.0000  , df=1
# parameter F test:         F=33.2929 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=10.9644 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=22.4969 , p=0.0000  , df=2
# likelihood ratio test: chi2=21.3081 , p=0.0000  , df=2
# parameter F test:         F=10.9644 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.5724  , p=0.0011  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=17.3332 , p=0.0006  , df=3
# likelihood ratio test: chi2=16.6126 , p=0.0008  , df=3
# parameter F test:         F=5.5724  , p=0.0011  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=5.0803  , p=0.0007  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=21.2994 , p=0.0003  , df=4
# likelihood ratio test: chi2=20.2196 , p=0.0005  , df=4
# parameter F test:         F=5.0803  , p=0.0007  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.4957  , p=0.0048  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=18.5235 , p=0.0024  , df=5
# likelihood ratio test: chi2=17.6957 , p=0.0034  , df=5
# parameter F test:         F=3.4957  , p=0.0048  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3252  , p=0.0346  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=14.9535 , p=0.0206  , df=6
# likelihood ratio test: chi2=14.4052 , p=0.0254  , df=6
# parameter F test:         F=2.3252  , p=0.0346  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5281  , p=0.1604  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=11.5985 , p=0.1146  , df=7
# likelihood ratio test: chi2=11.2633 , p=0.1275  , df=7
# parameter F test:         F=1.5281  , p=0.1604  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7891  , p=0.0820  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=15.7035 , p=0.0468  , df=8
# likelihood ratio test: chi2=15.0943 , p=0.0573  , df=8
# parameter F test:         F=1.7891  , p=0.0820  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5475  , p=0.1349  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=15.4660 , p=0.0789  , df=9
# likelihood ratio test: chi2=14.8717 , p=0.0945  , df=9
# parameter F test:         F=1.5475  , p=0.1349  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.4273  , p=0.1720  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=16.0469 , p=0.0983  , df=10
# likelihood ratio test: chi2=15.4052 , p=0.1180  , df=10
# parameter F test:         F=1.4273  , p=0.1720  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=25.1998 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=25.5855 , p=0.0000  , df=1
# likelihood ratio test: chi2=24.0694 , p=0.0000  , df=1
# parameter F test:         F=25.1998 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=10.8832 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=22.3302 , p=0.0000  , df=2
# likelihood ratio test: chi2=21.1583 , p=0.0000  , df=2
# parameter F test:         F=10.8832 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=9.0135  , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=28.0369 , p=0.0000  , df=3
# likelihood ratio test: chi2=26.2129 , p=0.0000  , df=3
# parameter F test:         F=9.0135  , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=5.6101  , p=0.0003  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=23.5203 , p=0.0001  , df=4
# likelihood ratio test: chi2=22.2127 , p=0.0002  , df=4
# parameter F test:         F=5.6101  , p=0.0003  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.4835  , p=0.0049  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=18.4587 , p=0.0024  , df=5
# likelihood ratio test: chi2=17.6365 , p=0.0034  , df=5
# parameter F test:         F=3.4835  , p=0.0049  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7311  , p=0.0145  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=17.5638 , p=0.0074  , df=6
# likelihood ratio test: chi2=16.8137 , p=0.0100  , df=6
# parameter F test:         F=2.7311  , p=0.0145  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7221  , p=0.1064  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=13.0708 , p=0.0704  , df=7
# likelihood ratio test: chi2=12.6472 , p=0.0812  , df=7
# parameter F test:         F=1.7221  , p=0.1064  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2702  , p=0.2619  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=11.1483 , p=0.1934  , df=8
# likelihood ratio test: chi2=10.8367 , p=0.2111  , df=8
# parameter F test:         F=1.2702  , p=0.2619  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0368  , p=0.4128  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=10.3617 , p=0.3220  , df=9
# likelihood ratio test: chi2=10.0904 , p=0.3432  , df=9
# parameter F test:         F=1.0368  , p=0.4128  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0799  , p=0.3803  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=12.1410 , p=0.2757  , df=10
# likelihood ratio test: chi2=11.7689 , p=0.3008  , df=10
# parameter F test:         F=1.0799  , p=0.3803  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=24.4091 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=24.7827 , p=0.0000  , df=1
# likelihood ratio test: chi2=23.3568 , p=0.0000  , df=1
# parameter F test:         F=24.4091 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=11.5176 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=23.6319 , p=0.0000  , df=2
# likelihood ratio test: chi2=22.3247 , p=0.0000  , df=2
# parameter F test:         F=11.5176 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.0476  , p=0.0002  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=21.9219 , p=0.0001  , df=3
# likelihood ratio test: chi2=20.7857 , p=0.0001  , df=3
# parameter F test:         F=7.0476  , p=0.0002  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.1045  , p=0.0033  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=17.2083 , p=0.0018  , df=4
# likelihood ratio test: chi2=16.4944 , p=0.0024  , df=4
# parameter F test:         F=4.1045  , p=0.0033  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.8168  , p=0.0178  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=14.9262 , p=0.0107  , df=5
# likelihood ratio test: chi2=14.3825 , p=0.0134  , df=5
# parameter F test:         F=2.8168  , p=0.0178  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7770  , p=0.0132  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=17.8589 , p=0.0066  , df=6
# likelihood ratio test: chi2=17.0841 , p=0.0090  , df=6
# parameter F test:         F=2.7770  , p=0.0132  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6192  , p=0.1326  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=12.2897 , p=0.0914  , df=7
# likelihood ratio test: chi2=11.9143 , p=0.1034  , df=7
# parameter F test:         F=1.6192  , p=0.1326  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1713  , p=0.3190  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=10.2803 , p=0.2459  , df=8
# likelihood ratio test: chi2=10.0145 , p=0.2640  , df=8
# parameter F test:         F=1.1713  , p=0.3190  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8836  , p=0.5411  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=8.8310  , p=0.4530  , df=9
# likelihood ratio test: chi2=8.6329  , p=0.4718  , df=9
# parameter F test:         F=0.8836  , p=0.5411  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1517  , p=0.3271  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=12.9476 , p=0.2266  , df=10
# likelihood ratio test: chi2=12.5255 , p=0.2514  , df=10
# parameter F test:         F=1.1517  , p=0.3271  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=39.7511 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=40.3595 , p=0.0000  , df=1
# likelihood ratio test: chi2=36.7477 , p=0.0000  , df=1
# parameter F test:         F=39.7511 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=11.2971 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=23.1795 , p=0.0000  , df=2
# likelihood ratio test: chi2=21.9201 , p=0.0000  , df=2
# parameter F test:         F=11.2971 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.3150  , p=0.0015  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=16.5325 , p=0.0009  , df=3
# likelihood ratio test: chi2=15.8754 , p=0.0012  , df=3
# parameter F test:         F=5.3150  , p=0.0015  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.1049  , p=0.0167  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=13.0175 , p=0.0112  , df=4
# likelihood ratio test: chi2=12.6034 , p=0.0134  , df=4
# parameter F test:         F=3.1049  , p=0.0167  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9679  , p=0.0854  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=10.4278 , p=0.0640  , df=5
# likelihood ratio test: chi2=10.1585 , p=0.0709  , df=5
# parameter F test:         F=1.9679  , p=0.0854  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5449  , p=0.1659  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=9.9349  , p=0.1274  , df=6
# likelihood ratio test: chi2=9.6888  , p=0.1384  , df=6
# parameter F test:         F=1.5449  , p=0.1659  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3833  , p=0.2149  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=10.4994 , p=0.1620  , df=7
# likelihood ratio test: chi2=10.2237 , p=0.1762  , df=7
# parameter F test:         F=1.3833  , p=0.2149  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2366  , p=0.2803  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=10.8537 , p=0.2101  , df=8
# likelihood ratio test: chi2=10.5581 , p=0.2280  , df=8
# parameter F test:         F=1.2366  , p=0.2803  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1995  , p=0.2982  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=11.9885 , p=0.2140  , df=9
# likelihood ratio test: chi2=11.6273 , p=0.2351  , df=9
# parameter F test:         F=1.1995  , p=0.2982  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9581  , p=0.0408  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=22.0140 , p=0.0150  , df=10
# likelihood ratio test: chi2=20.8293 , p=0.0223  , df=10
# parameter F test:         F=1.9581  , p=0.0408  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=20.6340 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=20.9498 , p=0.0000  , df=1
# likelihood ratio test: chi2=19.9188 , p=0.0000  , df=1
# parameter F test:         F=20.6340 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=8.0250  , p=0.0004  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=16.4659 , p=0.0003  , df=2
# likelihood ratio test: chi2=15.8169 , p=0.0004  , df=2
# parameter F test:         F=8.0250  , p=0.0004  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.6674  , p=0.0010  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=17.6287 , p=0.0005  , df=3
# likelihood ratio test: chi2=16.8841 , p=0.0007  , df=3
# parameter F test:         F=5.6674  , p=0.0010  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.4026  , p=0.0103  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=14.2653 , p=0.0065  , df=4
# likelihood ratio test: chi2=13.7701 , p=0.0081  , df=4
# parameter F test:         F=3.4026  , p=0.0103  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.0747  , p=0.0016  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=21.5915 , p=0.0006  , df=5
# likelihood ratio test: chi2=20.4777 , p=0.0010  , df=5
# parameter F test:         F=4.0747  , p=0.0016  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.0435  , p=0.0073  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=19.5728 , p=0.0033  , df=6
# likelihood ratio test: chi2=18.6472 , p=0.0048  , df=6
# parameter F test:         F=3.0435  , p=0.0073  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.6984  , p=0.0111  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=20.4805 , p=0.0046  , df=7
# likelihood ratio test: chi2=19.4651 , p=0.0068  , df=7
# parameter F test:         F=2.6984  , p=0.0111  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.5507  , p=0.0008  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=31.1647 , p=0.0001  , df=8
# likelihood ratio test: chi2=28.8796 , p=0.0003  , df=8
# parameter F test:         F=3.5507  , p=0.0008  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.0082  , p=0.0023  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=30.0645 , p=0.0004  , df=9
# likelihood ratio test: chi2=27.9206 , p=0.0010  , df=9
# parameter F test:         F=3.0082  , p=0.0023  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.8007  , p=0.0031  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=31.4872 , p=0.0005  , df=10
# likelihood ratio test: chi2=29.1347 , p=0.0012  , df=10
# parameter F test:         F=2.8007  , p=0.0031  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=41.8784 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=42.5194 , p=0.0000  , df=1
# likelihood ratio test: chi2=38.5354 , p=0.0000  , df=1
# parameter F test:         F=41.8784 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=21.9021 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=44.9391 , p=0.0000  , df=2
# likelihood ratio test: chi2=40.4996 , p=0.0000  , df=2
# parameter F test:         F=21.9021 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=15.5217 , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=48.2808 , p=0.0000  , df=3
# likelihood ratio test: chi2=43.1824 , p=0.0000  , df=3
# parameter F test:         F=15.5217 , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=8.4848  , p=0.0000  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=35.5728 , p=0.0000  , df=4
# likelihood ratio test: chi2=32.6888 , p=0.0000  , df=4
# parameter F test:         F=8.4848  , p=0.0000  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=6.4191  , p=0.0000  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=34.0141 , p=0.0000  , df=5
# likelihood ratio test: chi2=31.3528 , p=0.0000  , df=5
# parameter F test:         F=6.4191  , p=0.0000  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=4.1932  , p=0.0006  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=26.9660 , p=0.0001  , df=6
# likelihood ratio test: chi2=25.2492 , p=0.0003  , df=6
# parameter F test:         F=4.1932  , p=0.0006  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=4.0258  , p=0.0004  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=30.5552 , p=0.0001  , df=7
# ...
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=9.1703  , p=0.0000  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=38.4465 , p=0.0000  , df=4
# likelihood ratio test: chi2=35.1061 , p=0.0000  , df=4
# parameter F test:         F=9.1703  , p=0.0000  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=5.4950  , p=0.0001  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=29.1174 , p=0.0000  , df=5
# likelihood ratio test: chi2=27.1383 , p=0.0001  , df=5
# parameter F test:         F=5.4950  , p=0.0001  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.6100  , p=0.0189  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=16.7851 , p=0.0101  , df=6
# likelihood ratio test: chi2=16.0983 , p=0.0132  , df=6
# parameter F test:         F=2.6100  , p=0.0189  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.5051  , p=0.0177  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=19.0136 , p=0.0081  , df=7
# likelihood ratio test: chi2=18.1343 , p=0.0114  , df=7
# parameter F test:         F=2.5051  , p=0.0177  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.1510  , p=0.0335  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=18.8800 , p=0.0155  , df=8
# likelihood ratio test: chi2=18.0085 , p=0.0212  , df=8
# parameter F test:         F=2.1510  , p=0.0335  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9628  , p=0.0464  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=19.6165 , p=0.0204  , df=9
# likelihood ratio test: chi2=18.6732 , p=0.0281  , df=9
# parameter F test:         F=1.9628  , p=0.0464  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7484  , p=0.0738  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=19.6561 , p=0.0327  , df=10
# likelihood ratio test: chi2=18.7045 , p=0.0442  , df=10
# parameter F test:         F=1.7484  , p=0.0738  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=30.0355 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=30.4953 , p=0.0000  , df=1
# likelihood ratio test: chi2=28.3729 , p=0.0000  , df=1
# parameter F test:         F=30.0355 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=15.1733 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=31.1327 , p=0.0000  , df=2
# likelihood ratio test: chi2=28.9148 , p=0.0000  , df=2
# parameter F test:         F=15.1733 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=10.6843 , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=33.2337 , p=0.0000  , df=3
# likelihood ratio test: chi2=30.7105 , p=0.0000  , df=3
# parameter F test:         F=10.6843 , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=7.7717  , p=0.0000  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=32.5831 , p=0.0000  , df=4
# likelihood ratio test: chi2=30.1419 , p=0.0000  , df=4
# parameter F test:         F=7.7717  , p=0.0000  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.0669  , p=0.0016  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=21.5499 , p=0.0006  , df=5
# likelihood ratio test: chi2=20.4402 , p=0.0010  , df=5
# parameter F test:         F=4.0669  , p=0.0016  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.8768  , p=0.0012  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=24.9314 , p=0.0004  , df=6
# likelihood ratio test: chi2=23.4547 , p=0.0007  , df=6
# parameter F test:         F=3.8768  , p=0.0012  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=4.5121  , p=0.0001  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=34.2461 , p=0.0000  , df=7
# likelihood ratio test: chi2=31.5253 , p=0.0000  , df=7
# parameter F test:         F=4.5121  , p=0.0001  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.3493  , p=0.0014  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=29.3972 , p=0.0003  , df=8
# likelihood ratio test: chi2=27.3529 , p=0.0006  , df=8
# parameter F test:         F=3.3493  , p=0.0014  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.8527  , p=0.0037  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=28.5101 , p=0.0008  , df=9
# likelihood ratio test: chi2=26.5728 , p=0.0016  , df=9
# parameter F test:         F=2.8527  , p=0.0037  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.7077  , p=0.0042  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=30.4419 , p=0.0007  , df=10
# likelihood ratio test: chi2=28.2360 , p=0.0017  , df=10
# parameter F test:         F=2.7077  , p=0.0042  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=34.1031 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=34.6251 , p=0.0000  , df=1
# likelihood ratio test: chi2=31.9221 , p=0.0000  , df=1
# parameter F test:         F=34.1031 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=14.5975 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=29.9514 , p=0.0000  , df=2
# likelihood ratio test: chi2=27.8914 , p=0.0000  , df=2
# parameter F test:         F=14.5975 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.5223  , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=26.5087 , p=0.0000  , df=3
# likelihood ratio test: chi2=24.8706 , p=0.0000  , df=3
# parameter F test:         F=8.5223  , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=5.3966  , p=0.0004  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=22.6253 , p=0.0002  , df=4
# likelihood ratio test: chi2=21.4119 , p=0.0003  , df=4
# parameter F test:         F=5.3966  , p=0.0004  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.8422  , p=0.0169  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=15.0605 , p=0.0101  , df=5
# likelihood ratio test: chi2=14.5072 , p=0.0127  , df=5
# parameter F test:         F=2.8422  , p=0.0169  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.8274  , p=0.0118  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=18.1831 , p=0.0058  , df=6
# likelihood ratio test: chi2=17.3807 , p=0.0080  , df=6
# parameter F test:         F=2.8274  , p=0.0118  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.4035  , p=0.0019  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=25.8322 , p=0.0005  , df=7
# likelihood ratio test: chi2=24.2437 , p=0.0010  , df=7
# parameter F test:         F=3.4035  , p=0.0019  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3660  , p=0.0192  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=20.7664 , p=0.0078  , df=8
# likelihood ratio test: chi2=19.7183 , p=0.0115  , df=8
# parameter F test:         F=2.3660  , p=0.0192  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.8003  , p=0.0713  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=17.9923 , p=0.0353  , df=9
# likelihood ratio test: chi2=17.1946 , p=0.0458  , df=9
# parameter F test:         F=1.8003  , p=0.0713  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.6216  , p=0.1041  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=18.2308 , p=0.0512  , df=10
# likelihood ratio test: chi2=17.4084 , p=0.0658  , df=10
# parameter F test:         F=1.6216  , p=0.1041  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=34.8842 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=35.4181 , p=0.0000  , df=1
# likelihood ratio test: chi2=32.5965 , p=0.0000  , df=1
# parameter F test:         F=34.8842 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=22.8131 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=46.8082 , p=0.0000  , df=2
# likelihood ratio test: chi2=42.0172 , p=0.0000  , df=2
# parameter F test:         F=22.8131 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=9.7405  , p=0.0000  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=30.2980 , p=0.0000  , df=3
# likelihood ratio test: chi2=28.1824 , p=0.0000  , df=3
# parameter F test:         F=9.7405  , p=0.0000  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=6.3557  , p=0.0001  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=26.6464 , p=0.0000  , df=4
# likelihood ratio test: chi2=24.9841 , p=0.0001  , df=4
# parameter F test:         F=6.3557  , p=0.0001  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=5.1052  , p=0.0002  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=27.0520 , p=0.0001  , df=5
# likelihood ratio test: chi2=25.3328 , p=0.0001  , df=5
# parameter F test:         F=5.1052  , p=0.0002  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.9172  , p=0.0011  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=25.1912 , p=0.0003  , df=6
# likelihood ratio test: chi2=23.6848 , p=0.0006  , df=6
# parameter F test:         F=3.9172  , p=0.0011  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.9957  , p=0.0054  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=22.7373 , p=0.0019  , df=7
# likelihood ratio test: chi2=21.4946 , p=0.0031  , df=7
# parameter F test:         F=2.9957  , p=0.0054  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.0061  , p=0.0035  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=26.3850 , p=0.0009  , df=8
# likelihood ratio test: chi2=24.7228 , p=0.0017  , df=8
# parameter F test:         F=3.0061  , p=0.0035  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.9746  , p=0.0026  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=29.7285 , p=0.0005  , df=9
# likelihood ratio test: chi2=27.6301 , p=0.0011  , df=9
# parameter F test:         F=2.9746  , p=0.0026  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.5296  , p=0.0073  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=28.4390 , p=0.0015  , df=10
# likelihood ratio test: chi2=26.5017 , p=0.0031  , df=10
# parameter F test:         F=2.5296  , p=0.0073  , df_denom=169, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=32.9162 , p=0.0000  , df_denom=196, df_num=1
# ssr based chi2 test:   chi2=33.4200 , p=0.0000  , df=1
# likelihood ratio test: chi2=30.8930 , p=0.0000  , df=1
# parameter F test:         F=32.9162 , p=0.0000  , df_denom=196, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=14.1165 , p=0.0000  , df_denom=193, df_num=2
# ssr based chi2 test:   chi2=28.9643 , p=0.0000  , df=2
# likelihood ratio test: chi2=27.0321 , p=0.0000  , df=2
# parameter F test:         F=14.1165 , p=0.0000  , df_denom=193, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.9935  , p=0.0006  , df_denom=190, df_num=3
# ssr based chi2 test:   chi2=18.6430 , p=0.0003  , df=3
# likelihood ratio test: chi2=17.8129 , p=0.0005  , df=3
# parameter F test:         F=5.9935  , p=0.0006  , df_denom=190, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.3948  , p=0.0104  , df_denom=187, df_num=4
# ssr based chi2 test:   chi2=14.2328 , p=0.0066  , df=4
# likelihood ratio test: chi2=13.7398 , p=0.0082  , df=4
# parameter F test:         F=3.3948  , p=0.0104  , df_denom=187, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.5101  , p=0.0047  , df_denom=184, df_num=5
# ssr based chi2 test:   chi2=18.5998 , p=0.0023  , df=5
# likelihood ratio test: chi2=17.7654 , p=0.0033  , df=5
# parameter F test:         F=3.5101  , p=0.0047  , df_denom=184, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.0598  , p=0.0071  , df_denom=181, df_num=6
# ssr based chi2 test:   chi2=19.6774 , p=0.0032  , df=6
# likelihood ratio test: chi2=18.7422 , p=0.0046  , df=6
# parameter F test:         F=3.0598  , p=0.0071  , df_denom=181, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.2994  , p=0.0288  , df_denom=178, df_num=7
# ssr based chi2 test:   chi2=17.4524 , p=0.0147  , df=7
# likelihood ratio test: chi2=16.7079 , p=0.0194  , df=7
# parameter F test:         F=2.2994  , p=0.0288  , df_denom=178, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.2822  , p=0.0239  , df_denom=175, df_num=8
# ssr based chi2 test:   chi2=20.0314 , p=0.0102  , df=8
# likelihood ratio test: chi2=19.0539 , p=0.0146  , df=8
# parameter F test:         F=2.2822  , p=0.0239  , df_denom=175, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0159  , p=0.0402  , df_denom=172, df_num=9
# ssr based chi2 test:   chi2=20.1474 , p=0.0170  , df=9
# likelihood ratio test: chi2=19.1541 , p=0.0239  , df=9
# parameter F test:         F=2.0159  , p=0.0402  , df_denom=172, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.6306  , p=0.1016  , df_denom=169, df_num=10
# ssr based chi2 test:   chi2=18.3327 , p=0.0496  , df=10
# likelihood ratio test: chi2=17.5013 , p=0.0640  , df=10
# parameter F test:         F=1.6306  , p=0.1016  , df_denom=169, df_num=10
# [{'start_time': 0, 'end_time': 200, 'granger_matrix': array([[0.        , 0.38331835, 0.05063766],
#        [0.02142898, 0.        , 0.01722515],
#        [0.00819891, 0.2037043 , 0.        ]])}, {'start_time': 100, 'end_time': 300, 'granger_matrix': array([[0.        , 0.15754871, 0.0014727 ],
#        [0.05694765, 0.        , 0.03533954],
#        [0.02383994, 0.12937441, 0.        ]])}, {'start_time': 200, 'end_time': 400, 'granger_matrix': array([[0.        , 0.43082868, 0.28164665],
#        [0.0578338 , 0.        , 0.04752547],
#        [0.19385469, 0.56023042, 0.        ]])}, {'start_time': 300, 'end_time': 500, 'granger_matrix': array([[0.        , 0.03417845, 0.05285695],
#        [0.04302951, 0.        , 0.76561346],
#        [0.00239759, 0.119429  , 0.        ]])}, {'start_time': 400, 'end_time': 600, 'granger_matrix': array([[0.        , 0.37422693, 0.00293011],
#        [0.00397075, 0.        , 0.10555084],
#        [0.00099801, 0.00920812, 0.        ]])}, {'start_time': 500, 'end_time': 700, 'granger_matrix': array([[0.        , 0.12757685, 0.62796819],
#        [0.11766485, 0.        , 0.14367462],
#        [0.02734412, 0.00429246, 0.        ]])}, {'start_time': 600, 'end_time': 800, 'granger_matrix': array([[0.        , 0.05551767, 0.59119992],
#        [0.03745516, 0.        , 0.01601944],
#        [0.11196226, 0.02775926, 0.        ]])}, {'start_time': 700, 'end_time': 900, 'granger_matrix': array([[0.        , 0.19687001, 0.67315672],
#        [0.00740417, 0.        , 0.2248419 ],
#        [0.01645608, 0.00395312, 0.        ]])}, {'start_time': 800, 'end_time': 1000, 'granger_matrix': array([[0.        , 0.10840932, 0.25312198],
#        [0.08880966, 0.        , 0.38507176],
#        [0.03491974, 0.1490035 , 0.        ]])}]

# %% [markdown]
# The GC p-value indicates the statistical significance of the test results. A low p-value (typically below 0.05 or 0.01) suggests that the null hypothesis (that X does not Granger cause Y) can be rejected, meaning X significantly helps predict Y.
# If the p-value is large, we do not have enough evidence to say that X Granger causes Y.

# %% [markdown]
# # Plotting the GC values for easier visualization and interpretation

# %% [markdown]
# There are several ways to visually represent Granger Causality (GC) results from your DataFrame containing subject_id, phase_id, and the GC values per window. The best approach depends on what aspects of the results you want to emphasize (e.g., causality strength over time, between variables, or across subjects).
# Examples based on saving the GC values, the person_id and the phase_id in a dataframe. GC values per pair saved as a separate feature per row.

# %% [markdown]
# **Heatmaps (for GC values between variables)**
#
# A heatmap is useful for showing the strength of Granger causality between variables over different windows for each subject. You can create a heatmap per subject and window, with color intensity representing the GC p-values between each pair of variables.
#
# X-axis: The target variables (e.g., Var1, Var2, Var3, etc.).
# Y-axis: The source variables (e.g., Var1, Var2, Var3, etc.).
# Color intensity: The GC values (p-values or strength).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example GC values for a subject
subject_gc_values = gc_results_df.loc[gc_results_df['subject_id'] == 'subject1']

# Create a heatmap for a specific window
for index, row in subject_gc_values.iterrows():
    window_gc_values = row[4:].values.reshape((num_vars, num_vars))  # Reshape to original matrix size
    sns.heatmap(window_gc_values, annot=True, cmap='coolwarm', xticklabels=variables, yticklabels=variables)
    plt.title(f'Granger Causality for Subject {row["subject_id"]}, Phase {row["phase_id"]}, Window {index}')
    plt.show()

# %% [markdown]
# **Line Plot of GC Values Over Time (per variable pair)**
#
# A line plot shows how the strength of causality between variable pairs evolves over time (or windows). This visualization is effective when you want to see trends in GC strength across different windows.
#
# X-axis: Window time or window number.
# Y-axis: GC values (p-values or strength).
# Multiple lines: Each line represents the GC values for a specific variable pair (e.g., Var1->Var2, Var2->Var3).

# %%
import matplotlib.pyplot as plt

# Extract GC values for one subject
subject_gc_values = gc_results_df.loc[gc_results_df['subject_id'] == 'subject1']

# Loop through each pair of variables and plot their GC values over windows
for var_i in variables:
    for var_j in variables:
        if var_i != var_j:
            gc_series = subject_gc_values[f'{var_i}->{var_j}_pvalue']
            plt.plot(subject_gc_values['WindowStart'], gc_series, label=f'{var_i}->{var_j}')

plt.title('Granger Causality Over Time for Subject 1')
plt.xlabel('Window Start')
plt.ylabel('GC P-Value')
plt.legend()
plt.show()

# %% [markdown]
# **Correlation Heatmaps Between Variables (over GC values)**
#
# If you want to see how variables are related based on Granger causality across windows, you can compute the correlations of the GC values between variables and represent them in a correlation heatmap.

# %%
correlation_matrix = gc_results_df.iloc[:, 4:].corr()  # Compute correlation between GC values
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation of GC P-Values Between Variables')
plt.show()

# %% [markdown]
# **Box Plots (for comparing GC values across subjects)**
#
# Box plots can be used to compare the distribution of GC values across different subjects or phases for a specific variable pair. This is useful for spotting outliers and understanding the spread of GC values across subjects.
#
# X-axis: Subject or phase.
# Y-axis: GC values.
# Boxes: Show the median, quartiles, and outliers.
# Example (using seaborn):

# %%
import seaborn as sns

# Box plot for one variable pair across subjects
sns.boxplot(x='subject_id', y='Var1->Var2_pvalue', data=gc_results_df)
plt.title('Distribution of GC P-Values (Var1->Var2) Across Subjects')
plt.show()

# %% [markdown]
# **3D Surface Plot (for windowed GC values across multiple variable pairs)**
#
# A 3D surface plot can represent the change in GC values over time (windows) for each variable pair. This plot is useful when you want to explore GC strength in three dimensions: window, source variable, and target variable.
#
# X-axis: Variable pairs.
# Y-axis: Window number.
# Z-axis: GC values.

# %%
#the most representative maybe together with plotbox. We could plot it per Phase on average over patients with condition and without condition
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Example data
X = np.arange(len(gc_results_df))  # Window indices
Y = np.arange(num_pairs)  # Variable pairs
X, Y = np.meshgrid(X, Y)
Z = gc_results_df.iloc[:, 4:].values.T  # GC values for all windows and pairs

ax.plot_surface(X, Y, Z, cmap='viridis')
ax.set_xlabel('Window')
ax.set_ylabel('Variable Pair')
ax.set_zlabel('GC P-Value')
plt.title('3D Surface of GC P-Values Over Time')
plt.show()

# %% [markdown]
# # ML or DL exploration

# %% [markdown]
# We have the dataframe with the person_id, phase_id and GC pair-wise values. Separately, we also have another dataframe with some categorical data for each subject, such as gender or age range, and binary data for class A for each subject that represents if each subject has a disease or not. Use these two dataframes and a KNN model to predict Class A (if the subject has a disease).

# %%
#confirm standarization for GC is done per subject (it may also be done per phase)

# %%
import pandas as pd
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.pipeline import make_pipeline
import numpy as np

# Example DataFrames (replace with actual data)
gc_df = pd.DataFrame({
    'person_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
    'phase_id': ['rest', 'activity', 'rest', 'activity', 'rest'],
    'Var1->Var2_pvalue': [0.01, 0.05, 0.02, 0.06, 0.03],
    'Var2->Var3_pvalue': [0.03, 0.07, 0.01, 0.08, 0.04],
    'Var1->Var3_pvalue': [0.02, 0.06, 0.03, 0.09, 0.05]
})

subject_info_df = pd.DataFrame({
    'person_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
    'gender': ['M', 'F', 'M', 'F', 'M'],
    'age_range': ['20-30', '30-40', '20-30', '40-50', '30-40'],
    'Class A': [1, 0, 1, 0, 1]  # Binary label: 1 for disease, 0 for no disease
})

# Step 1: Merge the two DataFrames on person_id
merged_df = pd.merge(gc_df, subject_info_df, on='person_id')

# Step 2: One-hot encode categorical variables (gender, age_range, phase_id)
categorical_cols = ['gender', 'age_range', 'phase_id']
encoder = OneHotEncoder()
encoded_cats = encoder.fit_transform(merged_df[categorical_cols]).toarray()
encoded_cat_df = pd.DataFrame(encoded_cats, columns=encoder.get_feature_names_out(categorical_cols))

# Step 3: Prepare the final dataset by concatenating GC values and encoded categorical data
X = pd.concat([merged_df.drop(columns=categorical_cols + ['Class A', 'person_id']), encoded_cat_df], axis=1)
y = merged_df['Class A']  # Target variable
subject_ids = merged_df['person_id']  # Grouping by person_id for subject-wise splitting

# Step 4: Create the StratifiedGroupKFold object for cross-validation
skf = StratifiedGroupKFold(n_splits=5)

# Initialize lists to store performance metrics
accuracy_list = []
conf_matrix_list = []

# Step 5: Perform Stratified Group K-Fold Cross-Validation
for train_index, test_index in skf.split(X, y, groups=subject_ids):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Standardize the feature data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Step 6: Train the KNN model
    knn = KNeighborsClassifier(n_neighbors=3)
    knn.fit(X_train_scaled, y_train)

    # Step 7: Make predictions
    y_pred = knn.predict(X_test_scaled)

    # Step 8: Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)

    # Store performance metrics
    accuracy_list.append(accuracy)
    conf_matrix_list.append(conf_matrix)

# Output cross-validation results
print(f"Average Accuracy: {np.mean(accuracy_list):.2f}")
print("Confusion Matrices for Each Fold:")
for i, cm in enumerate(conf_matrix_list):
    print(f"Fold {i + 1} Confusion Matrix:")
    print(cm)

# %%
#if we were to use a simple 1D CNN:

import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# Example DataFrames (replace with actual data)
gc_df = pd.DataFrame({
    'person_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
    'phase_id': ['rest', 'activity', 'rest', 'activity', 'rest'],
    'Var1->Var2_pvalue': [0.01, 0.05, 0.02, 0.06, 0.03],
    'Var2->Var3_pvalue': [0.03, 0.07, 0.01, 0.08, 0.04],
    'Var1->Var3_pvalue': [0.02, 0.06, 0.03, 0.09, 0.05]
})

subject_info_df = pd.DataFrame({
    'person_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
    'gender': ['M', 'F', 'M', 'F', 'M'],
    'age_range': ['20-30', '30-40', '20-30', '40-50', '30-40'],
    'Class A': [1, 0, 1, 0, 1]  # Binary label: 1 for disease, 0 for no disease
})

# Step 1: Merge the two DataFrames on person_id
merged_df = pd.merge(gc_df, subject_info_df, on='person_id')

# Step 2: One-hot encode categorical variables (gender, age_range, phase_id)
categorical_cols = ['gender', 'age_range', 'phase_id']
encoder = OneHotEncoder()
encoded_cats = encoder.fit_transform(merged_df[categorical_cols]).toarray()
encoded_cat_df = pd.DataFrame(encoded_cats, columns=encoder.get_feature_names_out(categorical_cols))

# Step 3: Prepare the final dataset by concatenating GC values and encoded categorical data
X = pd.concat([merged_df.drop(columns=categorical_cols + ['Class A', 'person_id']), encoded_cat_df], axis=1)
y = merged_df['Class A']  # Target variable
subject_ids = merged_df['person_id']  # Grouping by person_id for subject-wise splitting

# Convert to numpy arrays for easier manipulation
X = X.values
y = y.values

# Step 4: Create the StratifiedGroupKFold object for cross-validation
skf = StratifiedGroupKFold(n_splits=5)

# Initialize lists to store performance metrics
accuracy_list = []
conf_matrix_list = []

# Step 5: Define a simple CNN model
def create_cnn(input_shape):
    model = Sequential()
    model.add(Conv1D(64, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Binary classification output
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Step 6: Perform Stratified Group K-Fold Cross-Validation
for train_index, test_index in skf.split(X, y, groups=subject_ids):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Standardize the feature data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Reshape the data to be 3D for Conv1D input (samples, timesteps, features)
    X_train_scaled = np.expand_dims(X_train_scaled, axis=2)
    X_test_scaled = np.expand_dims(X_test_scaled, axis=2)

    # Step 7: Create and train the CNN model
    model = create_cnn(input_shape=(X_train_scaled.shape[1], 1))
    model.fit(X_train_scaled, y_train, epochs=10, batch_size=8, verbose=0)

    # Step 8: Make predictions
    y_pred = (model.predict(X_test_scaled) > 0.5).astype("int32").flatten()

    # Step 9: Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)

    # Store performance metrics
    accuracy_list.append(accuracy)
    conf_matrix_list.append(conf_matrix)

# Output cross-validation results
print(f"Average Accuracy: {np.mean(accuracy_list):.2f}")
print("Confusion Matrices for Each Fold:")
for i, cm in enumerate(conf_matrix_list):
    print(f"Fold {i + 1} Confusion Matrix:")
    print(cm)

# %%
#to save any dataframe to a .csv file
df.to_csv('gc_results.csv', index=False)
